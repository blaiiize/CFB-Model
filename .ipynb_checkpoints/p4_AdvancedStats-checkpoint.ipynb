# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np

import os
import time

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait

import glob

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor

import warnings
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=ConvergenceWarning)

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# Importing existing data to be augmented with new features

# %%
directory = '/users/blaizelahman/Desktop/CFB Model/Original Data'
pattern = os.path.join(directory, '*model*.csv')

teamFiles = glob.glob(pattern)

teamDict = {}

for file in teamFiles:

    teamDF = pd.read_csv(file)

    if teamDF.shape[0] >= 56:

        # throwing out first 20 rows due to missing rolling_sum data
        teamDF = teamDF.drop(teamDF.index[:20])
        teamDF = teamDF.reset_index(drop = True)
    
        key = teamDF['School'][0]
        teamDict[key] = teamDF
    
        print(f'Added: {key}')
# Out:
# Added: Louisiana Tech
# Added: Southern Mississippi
# Added: Arizona State
# Added: Auburn
# Added: Texas Tech
# Added: Minnesota
# Added: NC State
# Added: Georgia
# Added: USC
# Added: South Florida
# Added: Wisconsin
# Added: Miami
# Added: Mississippi State
# Added: Houston
# Added: San José State
# Added: Oklahoma State
# Added: UCLA
# Added: Rice
# Added: Texas State
# Added: Iowa
# Added: Western Michigan
# Added: Charlotte
# Added: Florida International
# Added: Ole Miss
# Added: UTEP
# Added: Boston College
# Added: Troy
# Added: Wake Forest
# Added: Baylor
# Added: Bowling Green
# Added: TCU
# Added: Virginia
# Added: Utah State
# Added: Appalachian State
# Added: Michigan
# Added: New Mexico State
# Added: SMU
# Added: South Carolina
# Added: Georgia Southern
# Added: Vanderbilt
# Added: California
# Added: Ohio State
# Added: Louisiana Monroe
# Added: Louisiana
# Added: Eastern Michigan
# Added: UMass
# Added: Alabama
# Added: Miami (OH)
# Added: Iowa State
# Added: Arizona
# Added: UAB
# Added: Akron
# Added: Cincinnati
# Added: Virginia Tech
# Added: Tulane
# Added: Texas
# Added: Connecticut
# Added: Georgia Tech
# Added: Texas A&M
# Added: Tennessee
# Added: Michigan State
# Added: Northern Illinois
# Added: Buffalo
# Added: Temple
# Added: BYU
# Added: Navy
# Added: Pittsburgh
# Added: Washington State
# Added: LSU
# Added: Kent State
# Added: Stanford
# Added: UCF
# Added: Maryland
# Added: Florida State
# Added: North Carolina
# Added: Western Kentucky
# Added: Kansas State
# Added: San Diego State
# Added: Army
# Added: Tulsa
# Added: Duke
# Added: Memphis
# Added: Clemson
# Added: Syracuse
# Added: Hawai'i
# Added: East Carolina
# Added: Fresno State
# Added: UNLV
# Added: Nevada
# Added: Arkansas State
# Added: Old Dominion
# Added: Penn State
# Added: Notre Dame
# Added: South Alabama
# Added: Wyoming
# Added: Northwestern
# Added: Purdue
# Added: Colorado
# Added: Illinois
# Added: Idaho
# Added: New Mexico
# Added: Middle Tennessee
# Added: Oregon State
# Added: Kansas
# Added: Nebraska
# Added: Ball State
# Added: Boise State
# Added: Florida Atlantic
# Added: West Virginia
# Added: Colorado State
# Added: Washington
# Added: Central Michigan
# Added: Georgia State
# Added: Utah
# Added: Marshall
# Added: North Texas
# Added: Air Force
# Added: UT San Antonio
# Added: Oklahoma
# Added: Florida
# Added: Ohio
# Added: Toledo
# Added: Oregon
# Added: Louisville
# Added: Kentucky
# Added: Missouri
# Added: Rutgers
# Added: Arkansas
# Added: Indiana

# %% [markdown]
# Grabbing team talent composite rankings from collegefootballdata.com
# Stat is made by 24/7 Sports and is based off of recruit/transfer player rankings

# %%
# setting the download directory and Chrome settings
directory = "/Users/blaizelahman/Desktop/CFBData"
chromeOptions = webdriver.ChromeOptions()
prefs = {"download.default_directory": directory}
chromeOptions.add_experimental_option("prefs", prefs)

# creating Chrome driver
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()), options = chromeOptions)

# making a dictionary to hold team talent rankings
talentRatings = {}

# downloading team talent composite ratings for years 2015-2023 from collegefootballdata.com
for year in range(2015, 2024):

    # skipping 2020 because it has bad data
    if year == 2020: 
        continue
        
    try:
        url = f'https://collegefootballdata.com/exporter/talent?year={year}'
        driver.get(url)
        time.sleep(4) 
            
        # clicking the query button
        query = driver.find_element(By.XPATH, "//button[contains(span/text(), 'Query')]")
        query.click()
        time.sleep(3) 
            
        # clicking the export button
        export = driver.find_element(By.XPATH, "//button[contains(span/text(), 'Export')]")
        export.click()
        time.sleep(3)
        
        key = str(year)
            
        # grabs files from CFBData folder
        files = os.listdir(directory)
        
        # grab the file paths for all files ending in .csv
        filePaths = [os.path.join(directory, name) for name in files if name.endswith('.csv')]

        # grabbing the most recently made file out of those in paths
        file = max(filePaths, key=os.path.getctime)
            
        # loading csv file
        talentRatings[key] = pd.read_csv(file)

        # deleting the file after it has been added
        os.remove(file)

    except Exception as e:
        print(f'Cannot grab data for {year}. Error: {e}')

    print(f'Successfully grabbed data for {year}')

driver.quit()
# Out:
# Successfully grabbed data for 2015
# Successfully grabbed data for 2016
# Successfully grabbed data for 2017
# Successfully grabbed data for 2018
# Successfully grabbed data for 2019
# Successfully grabbed data for 2021
# Successfully grabbed data for 2022
# Successfully grabbed data for 2023

# %%
talentRatings['2023'].head(10)
# Out:
#    Year      School   Talent
# 0  2023     Alabama  1015.43
# 1  2023     Georgia   977.87
# 2  2023  Ohio State   974.79
# 3  2023   Texas A&M   925.92
# 4  2023     Clemson   917.88
# 5  2023       Texas   913.24
# 6  2023         LSU   899.31
# 7  2023         USC   896.41
# 8  2023    Oklahoma   884.97
# 9  2023      Oregon   874.74

# %% [markdown]
# Will need to keep in mind that military teams do not have talent ratings

# %% [markdown]
# Now we need to augment original team's dataframe with the ratings

# %%
for team, teamDF in teamDict.items():

    for year in teamDF['Year'].unique():
        
        # checks if year is in talentRating
        if str(year) in talentRatings.keys():

            # grabs the dataframe from that year and the talent rating of that team in that year
            talentDF = talentRatings[str(year)]
            talent = talentDF.loc[talentDF['School'] == team, 'Talent']

            # assigns talent column with the corresponding talent ratings for games in the given year
            teamDF.loc[teamDF['Year'] == year, 'talent'] = talent.values[0]

    teamDict[team] = teamDF

# %%
teamDict['Alabama']['talent'].unique()
# Out:
# array([    nan,  981.9 ,  982.66,  997.57,  978.54,  984.96, 1004.04,
#        1016.79, 1015.43])

# %% [markdown]
# Now let's merge the opponent's talent ratings

# %%
def mergeTalent(team):

    # making a copy of the teams dataframe from teamDict
    teamDF = teamDict[team].copy() 

    teamDF['talent_opp'] = np.nan

    # going through the dataframe and merging the opponent's talent rating column row by row
    for index, row in teamDF.iterrows():

        # grabbing year and each opponent's name to access their talent rating in talentRatings
        year = row['Year']
        oppName = row['School_opp']

        if str(year) in talentRatings.keys():

            yearDF = talentRatings[str(year)]

            
            # getting the opponent's talent rating column from the game they played the given team
            oppRow = yearDF[yearDF['School'] == oppName]

            if not oppRow.empty:

                oppTalent = oppRow.iloc[0]['Talent']
    
                # merging the opponent's talent column on the row the team plays them
                teamDF.loc[index, 'talent_opp'] = oppTalent 
        
    return teamDF

# %%
for team in teamDict.keys():
    
    updatedDF = mergeTalent(team)
    teamDict[team] = updatedDF
    print(f'Merged: {team}')
# Out:
# Merged: Boston College
# Merged: Rutgers
# Merged: Auburn
# Merged: North Texas
# Merged: Nebraska
# Merged: Oklahoma State
# Merged: Arizona State
# Merged: Eastern Michigan
# Merged: Louisiana
# Merged: Colorado State
# Merged: Idaho
# Merged: Illinois
# Merged: Air Force
# Merged: Kent State
# Merged: Louisiana Monroe
# Merged: Iowa
# Merged: Akron
# Merged: Ohio
# Merged: Georgia
# Merged: South Alabama
# Merged: Georgia Tech
# Merged: Western Kentucky
# Merged: Maryland
# Merged: Arizona
# Merged: Minnesota
# Merged: Pittsburgh
# Merged: Marshall
# Merged: Louisiana Tech
# Merged: Virginia Tech
# Merged: California
# Merged: Georgia Southern
# Merged: Rice
# Merged: Missouri
# Merged: UCF
# Merged: Kansas State
# Merged: Appalachian State
# Merged: Michigan
# Merged: Clemson
# Merged: Oregon
# Merged: Florida Atlantic
# Merged: Central Michigan
# Merged: Louisville
# Merged: Navy
# Merged: Washington State
# Merged: Tennessee
# Merged: Arkansas State
# Merged: Kansas
# Merged: Miami
# Merged: Alabama
# Merged: Vanderbilt
# Merged: USC
# Merged: Indiana
# Merged: UMass
# Merged: Utah State
# Merged: Baylor
# Merged: Tulsa
# Merged: Ole Miss
# Merged: BYU
# Merged: UTEP
# Merged: Syracuse
# Merged: Middle Tennessee
# Merged: Arkansas
# Merged: UT San Antonio
# Merged: Hawai'i
# Merged: Oregon State
# Merged: Southern Mississippi
# Merged: Florida State
# Merged: Texas A&M
# Merged: UAB
# Merged: Boise State
# Merged: Duke
# Merged: Colorado
# Merged: Northern Illinois
# Merged: Coastal Carolina
# Merged: Florida
# Merged: Wyoming
# Merged: Houston
# Merged: Cincinnati
# Merged: New Mexico
# Merged: Texas Tech
# Merged: Texas State
# Merged: Temple
# Merged: Wisconsin
# Merged: Purdue
# Merged: Liberty
# Merged: East Carolina
# Merged: Old Dominion
# Merged: Oklahoma
# Merged: Toledo
# Merged: Troy
# Merged: Ohio State
# Merged: Penn State
# Merged: Buffalo
# Merged: Nevada
# Merged: Florida International
# Merged: Iowa State
# Merged: Northwestern
# Merged: New Mexico State
# Merged: South Carolina
# Merged: Memphis
# Merged: Western Michigan
# Merged: Miami (OH)
# Merged: South Florida
# Merged: Fresno State
# Merged: Tulane
# Merged: NC State
# Merged: Virginia
# Merged: Georgia State
# Merged: Bowling Green
# Merged: Ball State
# Merged: Army
# Merged: UNLV
# Merged: San José State
# Merged: Stanford
# Merged: LSU
# Merged: Utah
# Merged: Charlotte
# Merged: Notre Dame
# Merged: SMU
# Merged: UCLA
# Merged: Washington
# Merged: Michigan State
# Merged: Texas
# Merged: West Virginia
# Merged: Mississippi State
# Merged: Connecticut
# Merged: Kentucky
# Merged: Wake Forest
# Merged: North Carolina
# Merged: San Diego State
# Merged: TCU

# %%
teamDict['Alabama'][-10:-1]
# Out:
#      Unnamed: 0.1  Unnamed: 0    Game Id   School Conference HomeAway  Points  \
# 183           203         893  401520250  Alabama        SEC     home      24
# 184           204         897  401520285  Alabama        SEC     away      40
# 185           205         901  401520310  Alabama        SEC     away      26
# 186           206         905  401520316  Alabama        SEC     home      24
# 187           207         909  401520333  Alabama        SEC     home      34
# 188           208         913  401520362  Alabama        SEC     home      42
# 189           209         917  401520386  Alabama        SEC     away      49
# 190           210         921  401520401  Alabama        SEC     home      66
# 191           211         925  401520427  Alabama        SEC     away      27
#
#      Week  Year  completionAttempts  defensiveTDs  firstDowns  fourthDownEff  \
# 183     4  2023               17.21           0.0        20.0            0.0
# 184     5  2023               10.13           1.0        17.0            0.0
# 185     6  2023               21.33           0.0        16.0            0.1
# 186     7  2023               10.21           0.0        18.0            0.0
# 187     8  2023               14.21           0.0        20.0            0.0
# 188    10  2023               15.23           0.0        28.0            0.0
# 189    11  2023               16.25           0.0        23.0            0.0
# 190    12  2023               19.24           1.0        21.0            0.0
# 191    13  2023               16.24           0.0        21.0            2.2
#
#      fumblesLost  fumblesRecovered  interceptionTDs  interceptionYards  \
# 183          0.0               0.0              0.0               37.0
# 184          0.0               0.0              1.0               41.0
# 185          1.0               0.0              0.0                0.0
# 186          0.0               0.0              NaN                NaN
# 187          1.0               1.0              NaN                NaN
# 188          0.0               0.0              0.0               10.0
# 189          1.0               1.0              0.0                0.0
# 190          0.0               0.0              0.0                2.0
# 191          0.0               1.0              0.0               22.0
#
#      interceptions  kickReturnTDs  kickReturnYards  kickReturns  \
# 183            1.0            NaN              NaN          NaN
# 184            0.0            0.0             73.0          3.0
# 185            1.0            0.0             80.0          3.0
# 186            0.0            NaN              NaN          NaN
# 187            1.0            0.0             21.0          1.0
# 188            0.0            0.0             88.0          4.0
# 189            1.0            0.0            103.0          4.0
# 190            0.0            0.0             58.0          3.0
# 191            0.0            0.0             17.0          1.0
#
#      kickingPoints  netPassingYards  passesDeflected  passesIntercepted  \
# 183           10.0            225.0              4.0                1.0
# 184           16.0            164.0              2.0                3.0
# 185            6.0            321.0              2.0                1.0
# 186            6.0            238.0              1.0                NaN
# 187           10.0            220.0              4.0                NaN
# 188            6.0            219.0              6.0                1.0
# 189            7.0            285.0              4.0                1.0
# 190           12.0            259.0              5.0                1.0
# 191            9.0            259.0              2.0                2.0
#
#      passingTDs  possessionTime  puntReturnTDs  puntReturnYards  puntReturns  \
# 183         1.0           34.23            0.0              4.0          1.0
# 184         0.0           30.10            0.0              0.4          1.0
# 185         3.0           29.09            0.0              0.1          1.0
# 186         2.0           29.49            0.0             11.0          1.0
# 187         2.0           32.19            0.0              0.7          1.0
# 188         0.0           33.33            NaN              NaN          NaN
# 189         3.0           32.06            0.0             22.0          2.0
# 190         3.0           26.29            1.0             96.0          3.0
# 191         2.0           32.43            0.0              0.3          2.0
#
#      qbHurries  rushingAttempts  rushingTDs  rushingYards  sacks  tackles  \
# 183        8.0             45.0         1.0         131.0    5.0     40.0
# 184        5.0             43.0         3.0         193.0    4.0     20.0
# 185        7.0             26.0         0.0          23.0    5.0     32.0
# 186        4.0             42.0         1.0         177.0    4.0     35.0
# 187        4.0             42.0         NaN         138.0    3.0     45.0
# 188        2.0             46.0         6.0         288.0    1.0     29.0
# 189        7.0             39.0         4.0         159.0    3.0     25.0
# 190        3.0             33.0         5.0         315.0    0.0     31.0
# 191        1.0             44.0         1.0         192.0    4.0     43.0
#
#      tacklesForLoss  thirdDownEff  totalFumbles  totalPenaltiesYards  \
# 183            10.0          6.13           1.0                 6.60
# 184             8.0          5.12           2.0                 6.40
# 185             6.0          4.12           4.0                14.99
# 186             7.0          6.14           1.0                 5.45
# 187             8.0          5.13           1.0                 1.50
# 188             1.0         11.14           NaN                 6.50
# 189             9.0          7.11           1.0                 6.64
# 190             2.0          6.90           1.0                 3.25
# 191             6.0          6.16           0.0                 8.72
#
#      totalYards  turnovers  yardsPerPass  yardsPerRushAttempt  totalTDs  \
# 183       356.0        1.0          10.7                  2.9       2.0
# 184       357.0        0.0          12.6                  4.5       4.0
# 185       344.0        2.0           9.7                  0.9       3.0
# 186       415.0        0.0          11.3                  4.2       3.0
# 187       358.0        2.0          10.5                  3.3       2.0
# 188       507.0        0.0           9.5                  6.3       6.0
# 189       444.0        2.0          11.4                  4.1       7.0
# 190       574.0        0.0          10.8                  9.5       9.0
# 191       451.0        0.0          10.8                  4.4       3.0
#
#             School_opp Conference_opp HomeAway_opp  Points_opp  Week_opp  \
# 183           Ole Miss            SEC         away          10         4
# 184  Mississippi State            SEC         home          17         5
# 185          Texas A&M            SEC         home          20         6
# 186           Arkansas            SEC         away          21         7
# 187          Tennessee            SEC         away          20         8
# 188                LSU            SEC         away          28        10
# 189           Kentucky            SEC         home          21        11
# 190        Chattanooga       Southern         away          10        12
# 191             Auburn            SEC         home          24        13
#
#      Year_opp  completionAttempts_opp  defensiveTDs_opp  firstDowns_opp  \
# 183      2023                   21.36               0.0            17.0
# 184      2023                   15.27               0.0            15.0
# 185      2023                   14.25               0.0            16.0
# 186      2023                   14.24               0.0            13.0
# 187      2023                   28.41               0.0            22.0
# 188      2023                   20.34               0.0            21.0
# 189      2023                   17.31               0.0            11.0
# 190      2023                   10.21               0.0            11.0
# 191      2023                    6.17               0.0            18.0
#
#      fourthDownEff_opp  fumblesLost_opp  fumblesRecovered_opp  \
# 183                3.4              0.0                   0.0
# 184                0.3              0.0                   0.0
# 185                0.1              0.0                   1.0
# 186                0.0              0.0                   0.0
# 187                0.3              1.0                   1.0
# 188                0.2              0.0                   0.0
# 189                0.1              1.0                   1.0
# 190                0.0              0.0                   0.0
# 191                0.0              1.0                   0.0
#
#      interceptionTDs_opp  interceptionYards_opp  interceptions_opp  \
# 183                  0.0                    0.0                1.0
# 184                  NaN                    NaN                3.0
# 185                  0.0                   15.0                1.0
# 186                  NaN                    NaN                0.0
# 187                  0.0                    0.0                0.0
# 188                  NaN                    NaN                1.0
# 189                  0.0                    0.0                1.0
# 190                  NaN                    NaN                1.0
# 191                  NaN                    NaN                2.0
#
#      kickReturnTDs_opp  kickReturnYards_opp  kickReturns_opp  \
# 183                0.0                 26.0              3.0
# 184                0.0                110.0              5.0
# 185                0.0                 26.0              3.0
# 186                0.0                 36.0              2.0
# 187                0.0                  0.0              1.0
# 188                0.0                 13.0              1.0
# 189                0.0                 30.0              2.0
# 190                0.0                 56.0              3.0
# 191                0.0                 67.0              4.0
#
#      kickingPoints_opp  netPassingYards_opp  passesDeflected_opp  \
# 183                4.0                245.0                  0.0
# 184                5.0                107.0                  0.0
# 185                8.0                239.0                  2.0
# 186                7.0                150.0                  3.0
# 187                8.0                271.0                  1.0
# 188                4.0                272.0                  3.0
# 189                3.0                158.0                  2.0
# 190                4.0                107.0                  1.0
# 191                6.0                 93.0                  3.0
#
#      passesIntercepted_opp  passingTDs_opp  possessionTime_opp  \
# 183                    1.0             0.0               25.37
# 184                    NaN             1.0               29.50
# 185                    1.0             1.0               30.51
# 186                    NaN             2.0               30.11
# 187                    1.0             2.0               27.41
# 188                    NaN             2.0               26.27
# 189                    1.0             1.0               27.54
# 190                    NaN             0.0               33.31
# 191                    NaN             1.0               27.17
#
#      puntReturnTDs_opp  puntReturnYards_opp  puntReturns_opp  qbHurries_opp  \
# 183                NaN                  NaN              NaN            1.0
# 184                NaN                  NaN              NaN            1.0
# 185                0.0                 46.0              2.0            3.0
# 186                0.0                  5.0              2.0            1.0
# 187                0.0                  5.0              1.0            3.0
# 188                NaN                  NaN              NaN            2.0
# 189                NaN                  NaN              NaN            3.0
# 190                NaN                  NaN              NaN            1.0
# 191                0.0                  5.0              2.0            2.0
#
#      rushingAttempts_opp  rushingTDs_opp  rushingYards_opp  sacks_opp  \
# 183                 29.0             1.0              56.0        4.0
# 184                 35.0             1.0             154.0        4.0
# 185                 35.0             1.0              67.0        6.0
# 186                 36.0             0.0             100.0        5.0
# 187                 38.0             0.0             133.0        4.0
# 188                 24.0             2.0             206.0        2.0
# 189                 24.0             2.0              95.0        0.0
# 190                 35.0             1.0             126.0        1.0
# 191                 42.0             2.0             244.0        1.0
#
#      tackles_opp  tacklesForLoss_opp  thirdDownEff_opp  totalFumbles_opp  \
# 183         38.0                 9.0              3.14               2.0
# 184         21.0                 7.0              5.13               NaN
# 185         34.0                 8.0              4.12               2.0
# 186         36.0                 5.0              4.14               NaN
# 187         35.0                 5.0              8.18               1.0
# 188         39.0                 3.0              4.90               NaN
# 189         34.0                 6.0              3.11               1.0
# 190         34.0                 1.0              4.14               NaN
# 191         45.0                 5.0              4.12               2.0
#
#      totalPenaltiesYards_opp  totalYards_opp  turnovers_opp  yardsPerPass_opp  \
# 183                     8.69           301.0            1.0               6.8
# 184                     3.15           261.0            3.0               4.0
# 185                     4.20           306.0            1.0               9.6
# 186                     2.13           250.0            0.0               6.3
# 187                     8.55           404.0            1.0               6.6
# 188                     8.60           478.0            1.0               8.0
# 189                     4.19           253.0            2.0               5.1
# 190                     5.25           233.0            1.0               5.1
# 191                     5.28           337.0            3.0               5.5
#
#      yardsPerRushAttempt_opp  totalTDs_opp  scoreDiff  pointTotal   Win  \
# 183                      1.9           1.0         14          34  True
# 184                      4.4           2.0         23          57  True
# 185                      1.9           2.0          6          46  True
# 186                      2.8           2.0          3          45  True
# 187                      3.5           2.0         14          54  True
# 188                      8.6           4.0         14          70  True
# 189                      4.0           3.0         28          70  True
# 190                      3.6           1.0         56          76  True
# 191                      5.8           3.0          3          51  True
#
#      rolling_sum_Points20  rolling_sum_firstDowns20  \
# 183                 772.0                     467.0
# 184                 776.0                     471.0
# 185                 757.0                     458.0
# 186                 741.0                     445.0
# 187                 741.0                     445.0
# 188                 734.0                     440.0
# 189                 721.0                     438.0
# 190                 750.0                     445.0
# 191                 753.0                     443.0
#
#      rolling_sum_fumblesLost20  rolling_sum_fumblesRecovered20  \
# 183                       12.0                            14.0
# 184                       11.0                            13.0
# 185                       10.0                            12.0
# 186                       10.0                            11.0
# 187                       10.0                            11.0
# 188                       11.0                            12.0
# 189                       11.0                            12.0
# 190                       12.0                            13.0
# 191                       12.0                            13.0
#
#      rolling_sum_interceptions20  rolling_sum_kickReturnYards20  \
# 183                         11.0                          454.0
# 184                         12.0                          432.0
# 185                         12.0                          490.0
# 186                         13.0                          570.0
# 187                         12.0                          557.0
# 188                         13.0                          578.0
# 189                         12.0                          648.0
# 190                         13.0                          715.0
# 191                         11.0                          716.0
#
#      rolling_sum_kickingPoints20  rolling_sum_netPassingYards20  \
# 183                        186.0                         5866.0
# 184                        194.0                         5789.0
# 185                        199.0                         5613.0
# 186                        195.0                         5375.0
# 187                        193.0                         5296.0
# 188                        192.0                         5095.0
# 189                        185.0                         5033.0
# 190                        184.0                         5105.0
# 191                        187.0                         5128.0
#
#      rolling_sum_passesDeflected20  rolling_sum_passesIntercepted20  \
# 183                           82.0                             11.0
# 184                           80.0                             11.0
# 185                           77.0                             14.0
# 186                           77.0                             15.0
# 187                           76.0                             14.0
# 188                           76.0                             12.0
# 189                           79.0                             13.0
# 190                           80.0                             14.0
# 191                           82.0                             14.0
#
#      rolling_sum_passingTDs20  rolling_sum_puntReturns20  \
# 183                      54.0                       48.0
# 184                      53.0                       46.0
# 185                      48.0                       42.0
# 186                      46.0                       41.0
# 187                      46.0                       41.0
# 188                      45.0                       42.0
# 189                      39.0                       39.0
# 190                      41.0                       39.0
# 191                      41.0                       33.0
#
#      rolling_sum_qbHurries20  rolling_sum_rushingAttempts20  \
# 183                     81.0                          708.0
# 184                     81.0                          727.0
# 185                     82.0                          729.0
# 186                     84.0                          719.0
# 187                     86.0                          724.0
# 188                     85.0                          740.0
# 189                     83.0                          754.0
# 190                     89.0                          769.0
# 191                     88.0                          763.0
#
#      rolling_sum_rushingTDs20  rolling_sum_rushingYards20  \
# 183                      37.0                      3435.0
# 184                      37.0                      3560.0
# 185                      37.0                      3506.0
# 186                      37.0                      3417.0
# 187                      38.0                      3523.0
# 188                      37.0                      3546.0
# 189                      42.0                      3556.0
# 190                      45.0                      3554.0
# 191                      47.0                      3596.0
#
#      rolling_sum_sacks20  rolling_sum_tacklesForLoss20  \
# 183                 68.0                         152.0
# 184                 68.0                         154.0
# 185                 65.0                         150.0
# 186                 67.0                         146.0
# 187                 65.0                         138.0
# 188                 65.0                         140.0
# 189                 66.0                         136.0
# 190                 66.0                         138.0
# 191                 62.0                         131.0
#
#      rolling_sum_totalFumbles20  rolling_sum_totalPenaltiesYards20  \
# 183                        29.0                            159.462
# 184                        27.0                            156.422
# 185                        28.0                            158.452
# 186                        30.0                            167.992
# 187                        31.0                            162.313
# 188                        31.0                            155.963
# 189                        31.0                            156.063
# 190                        32.0                            147.603
# 191                        30.0                            144.253
#
#      rolling_sum_totalYards20  rolling_sum_turnovers20  \
# 183                    9301.0                     23.0
# 184                    9349.0                     23.0
# 185                    9119.0                     22.0
# 186                    8792.0                     23.0
# 187                    8819.0                     22.0
# 188                    8641.0                     24.0
# 189                    8589.0                     23.0
# 190                    8659.0                     25.0
# 191                    8724.0                     23.0
#
#      rolling_sum_yardsPerPass20  rolling_sum_yardsPerRushAttempt20  \
# 183                       8.480                              4.705
# 184                       8.605                              4.840
# 185                       8.775                              4.765
# 186                       8.560                              4.655
# 187                       8.820                              4.770
# 188                       8.865                              4.715
# 189                       8.990                              4.595
# 190                       9.285                              4.465
# 191                       9.235                              4.590
#
#      rolling_sum_totalTDs20  rolling_sum_Points8  rolling_sum_firstDowns8  \
# 183                    95.0                271.0                    173.0
# 184                    94.0                265.0                    172.0
# 185                    90.0                274.0                    164.0
# 186                    88.0                270.0                    162.0
# 187                    89.0                260.0                    153.0
# 188                    86.0                245.0                    147.0
# 189                    85.0                231.0                    152.0
# 190                    90.0                256.0                    157.0
# 191                    90.0                305.0                    163.0
#
#      rolling_sum_fumblesLost8  rolling_sum_fumblesRecovered8  \
# 183                       4.0                            8.0
# 184                       4.0                            7.0
# 185                       4.0                            7.0
# 186                       4.0                            5.0
# 187                       2.0                            4.0
# 188                       3.0                            3.0
# 189                       3.0                            2.0
# 190                       4.0                            3.0
# 191                       3.0                            2.0
#
#      rolling_sum_interceptions8  rolling_sum_kickReturnYards8  \
# 183                         5.0                         218.0
# 184                         6.0                         218.0
# 185                         5.0                         291.0
# 186                         6.0                         340.0
# 187                         5.0                         332.0
# 188                         5.0                         237.0
# 189                         5.0                         302.0
# 190                         4.0                         387.0
# 191                         4.0                         423.0
#
#      rolling_sum_kickingPoints8  rolling_sum_netPassingYards8  \
# 183                        77.0                        1993.0
# 184                        75.0                        1957.0
# 185                        78.0                        1793.0
# 186                        72.0                        1905.0
# 187                        68.0                        1879.0
# 188                        71.0                        1756.0
# 189                        69.0                        1749.0
# 190                        66.0                        1779.0
# 191                        73.0                        1931.0
#
#      rolling_sum_passesDeflected8  rolling_sum_passesIntercepted8  \
# 183                          39.0                             4.0
# 184                          28.0                             5.0
# 185                          28.0                             8.0
# 186                          22.0                             9.0
# 187                          19.0                             7.0
# 188                          22.0                             7.0
# 189                          27.0                             7.0
# 190                          26.0                             8.0
# 191                          28.0                             8.0
#
#      rolling_sum_passingTDs8  rolling_sum_puntReturns8  \
# 183                     16.0                      12.0
# 184                     15.0                      13.0
# 185                     14.0                      14.0
# 186                     14.0                      15.0
# 187                     14.0                      14.0
# 188                     13.0                      13.0
# 189                     10.0                       7.0
# 190                     11.0                       8.0
# 191                     14.0                      10.0
#
#      rolling_sum_qbHurries8  rolling_sum_rushingAttempts8  \
# 183                    31.0                         289.0
# 184                    32.0                         307.0
# 185                    36.0                         320.0
# 186                    40.0                         310.0
# 187                    42.0                         307.0
# 188                    38.0                         315.0
# 189                    34.0                         321.0
# 190                    38.0                         325.0
# 191                    40.0                         316.0
#
#      rolling_sum_rushingTDs8  rolling_sum_rushingYards8  rolling_sum_sacks8  \
# 183                     16.0                     1225.0                25.0
# 184                     16.0                     1327.0                26.0
# 185                     17.0                     1383.0                24.0
# 186                     17.0                     1298.0                26.0
# 187                     16.0                     1212.0                30.0
# 188                     12.0                     1177.0                29.0
# 189                     13.0                     1260.0                27.0
# 190                     17.0                     1312.0                30.0
# 191                     20.0                     1424.0                25.0
#
#      rolling_sum_tacklesForLoss8  rolling_sum_totalFumbles8  \
# 183                         55.0                        9.0
# 184                         59.0                        7.0
# 185                         56.0                        9.0
# 186                         55.0                       12.0
# 187                         58.0                       11.0
# 188                         58.0                       11.0
# 189                         52.0                       10.0
# 190                         59.0                       11.0
# 191                         51.0                       11.0
#
#      rolling_sum_totalPenaltiesYards8  rolling_sum_totalYards8  \
# 183                            52.412                   3218.0
# 184                            55.812                   3284.0
# 185                            52.292                   3176.0
# 186                            61.832                   3203.0
# 187                            62.982                   3091.0
# 188                            53.380                   2933.0
# 189                            57.690                   3009.0
# 190                            53.430                   3091.0
# 191                            51.330                   3355.0
#
#      rolling_sum_turnovers8  rolling_sum_yardsPerPass8  \
# 183                     9.0                     7.9375
# 184                    10.0                     8.3875
# 185                     9.0                     9.1625
# 186                    10.0                     9.5875
# 187                     7.0                     9.9000
# 188                     8.0                     9.7875
# 189                     8.0                     9.8000
# 190                     8.0                    10.0500
# 191                     7.0                    10.8125
#
#      rolling_sum_yardsPerRushAttempt8  rolling_sum_totalTDs8  \
# 183                            4.0750                   32.0
# 184                            4.3000                   31.0
# 185                            4.2875                   32.0
# 186                            4.0250                   32.0
# 187                            3.8250                   31.0
# 188                            3.6000                   26.0
# 189                            3.7500                   24.0
# 190                            3.8750                   29.0
# 191                            4.4625                   36.0
#
#      rolling_sum_Points20_opp  rolling_sum_firstDowns20_opp  \
# 183                     696.0                         484.0
# 184                     651.0                         443.0
# 185                     562.0                         404.0
# 186                     611.0                         422.0
# 187                     834.0                         485.0
# 188                     739.0                         506.0
# 189                     493.0                         357.0
# 190                     577.0                         434.0
# 191                     529.0                         360.0
#
#      rolling_sum_fumblesLost20_opp  rolling_sum_fumblesRecovered20_opp  \
# 183                            9.0                                23.0
# 184                           14.0                                17.0
# 185                           16.0                                22.0
# 186                           12.0                                16.0
# 187                           13.0                                16.0
# 188                           12.0                                12.0
# 189                           10.0                                13.0
# 190                            6.0                                18.0
# 191                           13.0                                16.0
#
#      rolling_sum_interceptions20_opp  rolling_sum_kickReturnYards20_opp  \
# 183                             13.0                              683.0
# 184                             11.0                             1289.0
# 185                             11.0                              781.0
# 186                             12.0                              374.2
# 187                              7.0                              448.0
# 188                              8.0                              539.0
# 189                             17.0                              760.0
# 190                             19.0                              679.0
# 191                             17.0                              917.0
#
#      rolling_sum_kickingPoints20_opp  rolling_sum_netPassingYards20_opp  \
# 183                            168.0                             5187.0
# 184                            139.0                             6095.0
# 185                            152.0                             4697.0
# 186                            145.0                             4494.0
# 187                            184.0                             5690.0
# 188                            151.0                             5864.0
# 189                            115.0                             4156.0
# 190                            152.0                             5135.0
# 191                            141.0                             3146.0
#
#      rolling_sum_passesDeflected20_opp  rolling_sum_passesIntercepted20_opp  \
# 183                               81.0                                 16.0
# 184                               59.0                                 19.0
# 185                               76.0                                  7.0
# 186                               70.0                                 15.0
# 187                               70.0                                 17.0
# 188                               67.0                                 14.0
# 189                               51.0                                 17.0
# 190                                5.0                                 17.0
# 191                               68.0                                 16.0
#
#      rolling_sum_passingTDs20_opp  rolling_sum_puntReturns20_opp  \
# 183                          34.0                           24.0
# 184                          55.0                           32.0
# 185                          38.0                           47.0
# 186                          40.0                           29.0
# 187                          49.0                           33.0
# 188                          42.0                           15.0
# 189                          36.0                           22.0
# 190                          36.0                           22.0
# 191                          24.0                           32.0
#
#      rolling_sum_qbHurries20_opp  rolling_sum_rushingAttempts20_opp  \
# 183                         76.0                              861.0
# 184                         47.0                              486.0
# 185                         52.0                              637.0
# 186                         60.0                              848.0
# 187                        112.0                              801.0
# 188                         62.0                              739.0
# 189                         49.0                              631.0
# 190                          3.0                              763.0
# 191                         52.0                              806.0
#
#      rolling_sum_rushingTDs20_opp  rolling_sum_rushingYards20_opp  \
# 183                          49.0                          4417.0
# 184                          23.0                          1943.0
# 185                          24.0                          2909.0
# 186                          31.0                          3623.0
# 187                          55.0                          4275.0
# 188                          53.0                          3888.0
# 189                          22.0                          2686.0
# 190                          29.0                          2904.0
# 191                          36.0                          4155.0
#
#      rolling_sum_sacks20_opp  rolling_sum_tacklesForLoss20_opp  \
# 183                     62.0                             131.0
# 184                     45.0                             128.0
# 185                     55.0                             140.0
# 186                     60.0                             124.0
# 187                     57.0                             149.0
# 188                     38.0                              99.0
# 189                     36.0                             106.0
# 190                      4.0                               6.0
# 191                     45.0                             114.0
#
#      rolling_sum_totalFumbles20_opp  rolling_sum_totalPenaltiesYards20_opp  \
# 183                            30.0                                147.017
# 184                            24.0                                121.757
# 185                            31.0                                131.350
# 186                            31.0                                138.917
# 187                            26.0                                165.059
# 188                            18.0                                133.520
# 189                            19.0                                141.698
# 190                            16.0                                 90.460
# 191                            29.0                                143.715
#
#      rolling_sum_totalYards20_opp  rolling_sum_turnovers20_opp  \
# 183                        9604.0                         22.0
# 184                        8038.0                         25.0
# 185                        7606.0                         27.0
# 186                        8117.0                         24.0
# 187                        9965.0                         20.0
# 188                        9752.0                         20.0
# 189                        6842.0                         27.0
# 190                        8039.0                         25.0
# 191                        7301.0                         30.0
#
#      rolling_sum_yardsPerPass20_opp  rolling_sum_yardsPerRushAttempt20_opp  \
# 183                           8.670                                  4.935
# 184                           6.800                                  3.890
# 185                           7.435                                  4.455
# 186                           8.460                                  4.185
# 187                           8.955                                  5.450
# 188                           8.895                                  5.245
# 189                           7.520                                  4.320
# 190                           8.815                                  3.795
# 191                           6.345                                  5.005
#
#      rolling_sum_totalTDs20_opp  rolling_sum_Points8_opp  \
# 183                        85.0                    272.0
# 184                        84.0                    239.0
# 185                        65.0                    271.0
# 186                        76.0                    236.0
# 187                       108.0                    277.0
# 188                        96.0                    383.0
# 189                        62.0                    219.0
# 190                        67.0                    224.0
# 191                        63.0                    199.0
#
#      rolling_sum_firstDowns8_opp  rolling_sum_fumblesLost8_opp  \
# 183                        185.0                           5.0
# 184                        149.0                           4.0
# 185                        171.0                           8.0
# 186                        148.0                           2.0
# 187                        166.0                           4.0
# 188                        213.0                           1.0
# 189                        137.0                           4.0
# 190                        165.0                           3.0
# 191                        142.0                           1.0
#
#      rolling_sum_fumblesRecovered8_opp  rolling_sum_interceptions8_opp  \
# 183                                9.0                             3.0
# 184                                5.0                             6.0
# 185                                6.0                             4.0
# 186                                4.0                             7.0
# 187                                4.0                             4.0
# 188                                2.0                             3.0
# 189                                2.0                             6.0
# 190                                7.0                             7.0
# 191                                3.0                             8.0
#
#      rolling_sum_kickReturnYards8_opp  rolling_sum_kickingPoints8_opp  \
# 183                             195.0                            72.0
# 184                             445.0                            59.0
# 185                             268.0                            79.0
# 186                             249.0                            64.0
# 187                             149.0                            67.0
# 188                             222.0                            79.0
# 189                             240.0                            45.0
# 190                             313.0                            70.0
# 191                             376.0                            53.0
#
#      rolling_sum_netPassingYards8_opp  rolling_sum_passesDeflected8_opp  \
# 183                            2143.0                              27.0
# 184                            1932.0                              21.0
# 185                            2000.0                              29.0
# 186                            1690.0                              28.0
# 187                            1697.0                              29.0
# 188                            2646.0                              32.0
# 189                            1528.0                              21.0
# 190                            2002.0                               1.0
# 191                            1192.0                              30.0
#
#      rolling_sum_passesIntercepted8_opp  rolling_sum_passingTDs8_opp  \
# 183                                 4.0                         16.0
# 184                                 9.0                         17.0
# 185                                 3.0                         18.0
# 186                                 7.0                         17.0
# 187                                 7.0                         13.0
# 188                                 8.0                         27.0
# 189                                 8.0                         14.0
# 190                                 7.0                         12.0
# 191                                 6.0                         12.0
#
#      rolling_sum_puntReturns8_opp  rolling_sum_qbHurries8_opp  \
# 183                           7.0                        27.0
# 184                          12.0                        19.0
# 185                          23.0                        21.0
# 186                          12.0                        16.0
# 187                          17.0                        32.0
# 188                           2.0                        23.0
# 189                           2.0                        24.0
# 190                           6.0                         1.0
# 191                          13.0                        21.0
#
#      rolling_sum_rushingAttempts8_opp  rolling_sum_rushingTDs8_opp  \
# 183                             338.0                         15.0
# 184                             225.0                         10.0
# 185                             287.0                         11.0
# 186                             299.0                          7.0
# 187                             305.0                         19.0
# 188                             292.0                         22.0
# 189                             221.0                         12.0
# 190                             300.0                         11.0
# 191                             312.0                         11.0
#
#      rolling_sum_rushingYards8_opp  rolling_sum_sacks8_opp  \
# 183                         1709.0                    24.0
# 184                          943.0                    17.0
# 185                         1356.0                    29.0
# 186                          882.0                    23.0
# 187                         1883.0                    31.0
# 188                         1796.0                    16.0
# 189                         1135.0                    17.0
# 190                         1047.0                     1.0
# 191                         1590.0                    17.0
#
#      rolling_sum_tacklesForLoss8_opp  rolling_sum_totalFumbles8_opp  \
# 183                             56.0                           10.0
# 184                             57.0                            7.0
# 185                             65.0                           14.0
# 186                             55.0                           13.0
# 187                             70.0                           10.0
# 188                             42.0                            4.0
# 189                             49.0                            7.0
# 190                              1.0                            3.0
# 191                             49.0                            6.0
#
#      rolling_sum_totalPenaltiesYards8_opp  rolling_sum_totalYards8_opp  \
# 183                                57.726                       3852.0
# 184                                38.120                       2875.0
# 185                                52.800                       3356.0
# 186                                52.955                       2572.0
# 187                                65.015                       3580.0
# 188                                56.190                       4442.0
# 189                                53.378                       2663.0
# 190                                43.110                       3049.0
# 191                                44.740                       2782.0
#
#      rolling_sum_turnovers8_opp  rolling_sum_yardsPerPass8_opp  \
# 183                         8.0                         8.6875
# 184                        10.0                         6.6375
# 185                        12.0                         8.4875
# 186                         9.0                         7.8375
# 187                         8.0                         6.6875
# 188                         4.0                        10.7750
# 189                        10.0                         6.6375
# 190                        10.0                         8.6000
# 191                         9.0                         6.8000
#
#      rolling_sum_yardsPerRushAttempt8_opp  rolling_sum_totalTDs8_opp   talent  \
# 183                                4.7000                       32.0  1015.43
# 184                                4.0125                       30.0  1015.43
# 185                                4.6375                       31.0  1015.43
# 186                                2.8750                       28.0  1015.43
# 187                                6.3750                       35.0  1015.43
# 188                                6.2750                       50.0  1015.43
# 189                                4.9125                       29.0  1015.43
# 190                                3.5125                       24.0  1015.43
# 191                                4.9000                       24.0  1015.43
#
#      talent_opp
# 183      756.04
# 184      746.29
# 185      925.92
# 186      730.93
# 187      821.07
# 188      899.31
# 189      740.54
# 190      201.79
# 191      770.94

# %% [markdown]
# We can see if it's a valuable test statistic, let's build on our earlier model to include talent as a feature

# %% [markdown]
# First let's recreate our predictMissing function, this time adding in a set random state for better reproducibility

# %%
# slightly modifying predictMissing to take fixCols as an argument so that it's easier to add columns
def predictMissing(modelTeam, fixCols, randomState):
                   
    for col in fixCols:

        # replacing zeroes with null values 
        modelTeam[col].replace(0, np.nan, inplace=True) 
        
        # creating a boolean series to show which indeces are non-nulls
        nonNulls = ~modelTeam[col].isnull()
    
        if nonNulls.any():

            # setting up X and y data for making a linear model based off the existing data
            X = modelTeam.loc[nonNulls, ['scoreDiff']].values.reshape(-1, 1)
            y = modelTeam.loc[nonNulls, col].values.reshape(-1, 1)
            
            # fit linear regression model on known data
            lr = LinearRegression()
            lr.fit(X, y)
            
            # grabbing rows where scoreDiff exists but the predictor is missing
            missingVals = modelTeam.loc[modelTeam[col].isnull(), ['scoreDiff']].values.reshape(-1, 1)
            
            if missingVals.shape[0] > 0:

                 # predicting values for the missing rows based on scoreDiff
                preds = lr.predict(missingVals).flatten()
                
                # grabbing the standard deviation of the existing data
                std = modelTeam[col].std(skipna = True)

                # setting the random state that the sampleVals will be predicted from
                random = np.random.default_rng(seed = randomState)

                # using the predicted values to generate a random distribution based off of the predictions
                # and spread of the existing data
                sampleVals = random.normal(loc = preds, scale = std, size = len(preds))
                
                # replacing the null values with generated sample values
                modelTeam.loc[modelTeam[col].isnull(), col] = sampleVals

# %%
# picking out the columns with missing data (now including talent)
rollingCols = [col for col in teamDict['Florida State'].columns if 'rolling_sum' in col]
fixCols = [col for col in rollingCols if any(word in col for word in ['tackle', 'sacks', 'Deflected', 'defensive', 'qbHurries', 'fumbles', 'kickReturn', 'penalty', 'Fumble'])]
fixCols.extend(['talent','talent_opp'])

# %% [markdown]
# Making a model building function that will also include bootstrap aggregation when predicting results. Also using grid search to find the best number of n estimators.

# %%
def buildModel(modelTeam, randomState):

    # throwing out first 20 rows due to missing rolling_sum data
    modelTeam = modelTeam.drop(modelTeam.index[:20])
    modelTeam = modelTeam.reset_index(drop = True)

    # calling function to predict the missing values
    predictMissing(modelTeam, fixCols, randomState)

    features = [col for col in modelTeam.columns if 'rolling_sum' in col or 'talent' in col]
    
    # setting up training and test sets
    X = modelTeam[features]
    y = modelTeam[['scoreDiff']].values.ravel()


    xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.2)

    # setting up pipeline
    pipe = Pipeline([
        ('imputer', SimpleImputer(strategy = 'constant', fill_value = 0)),
        ('scaler', StandardScaler()),
        ('regressor', Lasso())
    ])

    # setting up and performing grid search to find best alpha level
    paramGrid = {
        'regressor__alpha': np.logspace(-4, 4, 50)
    }

    gridSearch = GridSearchCV(pipe, paramGrid, cv = 5, scoring = 'neg_mean_absolute_error')

    gridSearch.fit(X, y)

    bestAlpha = gridSearch.best_params_['regressor__alpha']

    print(f'Best alpha level: {bestAlpha}')

    # setting up new pipeline with the ideal alpha level and a bagging regressor
    betterPipe = Pipeline([
        ('imputer', SimpleImputer(strategy = 'constant', fill_value = 0)),
        ('scaler', StandardScaler()),
        ('regressor', BaggingRegressor(estimator = Lasso(alpha = bestAlpha), n_estimators = 50, n_jobs = -1))
    ])

    betterPipe.fit(xTrain, yTrain)

    testPreds = betterPipe.predict(xTest)

    # grabbing mean MAE
    cvScore = cross_val_score(betterPipe, xTrain, yTrain, cv = 5, scoring = 'neg_mean_absolute_error')
    print('Mean MAE: ', -cvScore.mean())

    # getting R2 scores from model
    trainPreds = betterPipe.predict(xTrain)
    testPreds = betterPipe.predict(xTest)
    print('Training R2 score: ' + str(r2_score(yTrain, trainPreds)))
    print('Test R2 score: ' + str(r2_score(yTest, testPreds)))

# %%
FSU = teamDict['Florida State']
buildModel(FSU, 50)
# Out:
# Best alpha level: 0.8286427728546842
# Mean MAE:  13.436705082603051
# Training R2 score: 0.673470779133823
# Test R2 score: 0.51973491054485

# %% [markdown]
# Can see that MAE and R2 score improved, let's see if this improved it across all teams

# %% [markdown]
# Adapting build function to just give MAE and R2 scores

# %%
def buildModelScore(modelTeam, features, randomState):

    # throwing out first 20 rows due to missing rolling_sum data
    modelTeam = modelTeam.drop(modelTeam.index[:20])
    modelTeam = modelTeam.reset_index(drop = True)

    # calling function to predict the missing values
    predictMissing(modelTeam, fixCols, randomState)
    
    # setting up training and test sets
    X = modelTeam[features]
    y = modelTeam[['scoreDiff']].values.ravel()

    xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size = 0.2)

    # setting up pipeline
    pipe = Pipeline([
        ('imputer', SimpleImputer(strategy = 'constant', fill_value = 0)),
        ('scaler', StandardScaler()),
        ('regressor', Lasso(max_iter = 3000))
    ])

    # setting up and performing grid search to find best alpha level
    paramGrid = {
        'regressor__alpha': np.logspace(-4, 4, 50)
    }

    gridSearch = GridSearchCV(pipe, paramGrid, cv = 5, scoring = 'neg_mean_absolute_error')

    gridSearch.fit(X, y)
    
    bestAlpha = gridSearch.best_params_['regressor__alpha']

    # setting up new pipeline with the ideal alpha level and a bagging regressor
    betterPipe = Pipeline([
        ('imputer', SimpleImputer(strategy = 'constant', fill_value = 0)),
        ('scaler', StandardScaler()),
        ('regressor', BaggingRegressor(estimator = Lasso(alpha = bestAlpha, max_iter = 3000), n_estimators = 50, n_jobs = -1))
    ])

    betterPipe.fit(xTrain, yTrain)

    testPreds = betterPipe.predict(xTest)

    # grabbing mean MAE
    cvScore = cross_val_score(betterPipe, xTrain, yTrain, cv = 5, scoring = 'neg_mean_absolute_error')

    # grabbing r2 score
    r2 = r2_score(yTest, testPreds)

    modelScores = [-cvScore.mean(), r2]
    
    return modelScores

# %% [markdown]
# Adding talent to the list of features considered

# %%
features = [col for col in teamDict['Florida State'].columns if 'rolling_sum' in col]
features.extend(['talent', 'talent_opp'])

# %%
# dictionary to hold each team and their model's score with talent as the newest added feature
modelScoresTalent = {}

for team, teamDF in teamDict.items():

    scores = buildModelScore(teamDF, features, 50)
    modelScoresTalent[team] = scores
    print(f'{team}: {scores}')
# Out:
# Louisiana Tech: [11.7092185648993, 0.2834725914463776]
# Southern Mississippi: [12.512968356634767, 0.48142385675241517]
# Arizona State: [10.0131904137656, 0.6343732756819935]
# Auburn: [11.731518085150114, 0.600949284264241]
# Texas Tech: [13.703953160132935, 0.46141379191486054]
# Minnesota: [13.847382247912865, 0.28179605448064493]
# NC State: [10.15960675046146, 0.6712633087841854]
# Georgia: [10.345260547194272, 0.7817468758716233]
# USC: [11.477034034723705, 0.359913427598067]
# South Florida: [10.90741580824148, 0.5526473384296506]
# Wisconsin: [12.295591566380098, 0.39575580055653137]
# Miami: [13.167654795573913, 0.5001615858925539]
# Mississippi State: [11.858168884437877, 0.5427012177994603]
# Houston: [13.962928192432992, 0.3687665797069921]
# San José State: [10.71094670316715, 0.36816342964095605]
# Oklahoma State: [14.753525526364934, 0.47806039020283564]
# UCLA: [14.166815021695546, 0.4506349125954098]
# Rice: [10.353438722081396, 0.3622511171305137]
# Texas State: [13.593413140781314, 0.308035534421234]
# Iowa: [12.338544379635792, 0.47870380129731194]
# Western Michigan: [12.978879955873618, 0.2396534062247151]
# Charlotte: [10.4874043092676, 0.024134436154360395]
# Florida International: [13.44978000060801, 0.18609625580420797]
# Ole Miss: [11.70206839346992, 0.6328979945756907]
# UTEP: [10.574685048276704, 0.4322407146281122]
# Boston College: [11.245133089394074, 0.6437320275893634]
# Troy: [11.303884482570684, 0.6433219260906554]
# Wake Forest: [13.238246573594287, 0.3958219985878345]
# Baylor: [13.698298928248997, 0.6777555742494689]
# Bowling Green: [14.404502503350164, 0.46617121789904725]
# TCU: [15.675596108355643, 0.29103745684573945]
# Virginia: [12.246715299327718, 0.43812804858579]
# Utah State: [13.498362242829401, 0.4787775241940584]
# Appalachian State: [12.52834966895653, 0.37918341506666475]
# Michigan: [13.086358391672286, 0.42544667227855637]
# New Mexico State: [12.42493136722104, 0.5783648243646051]
# SMU: [14.054759955693616, 0.5071347436503454]
# South Carolina: [9.840288659171819, 0.426230523463344]
# Georgia Southern: [12.755693102125736, -0.34027568038316947]
# Vanderbilt: [14.167451149176404, 0.5626375137373625]
# California: [11.097643067075564, 0.5282038013974748]
# Ohio State: [13.865417652676744, 0.36119390134998663]
# Louisiana Monroe: [12.522414477608084, 0.5466976968799518]
# Louisiana: [11.052603310609536, 0.33421500648744873]
# Eastern Michigan: [12.046727706995735, 0.2510374194446162]
# UMass: [16.460150698613486, -0.08999477252597643]
# Alabama: [10.783765686277782, 0.27860023515048893]
# Miami (OH): [10.692423847838572, 0.5536345661855775]
# Iowa State: [13.034778794111006, 0.3780873796274331]
# Arizona: [13.303771873208447, 0.5078403875590931]
# UAB: [13.257269730350242, 0.6243653969825232]
# Akron: [11.710788361694105, 0.44853333243423776]
# Cincinnati: [13.808565711017513, 0.3215310187131597]
# Virginia Tech: [13.961671137570352, 0.3829106850675651]
# Tulane: [11.141883168786347, 0.7433367366224761]
# Texas: [13.643190618579458, 0.4665959998162551]
# Connecticut: [12.544571882072203, 0.4585650459388739]
# Georgia Tech: [12.719106526418624, 0.10455655470014391]
# Texas A&M: [10.704034268669508, 0.6567532630149497]
# Tennessee: [12.427454498846453, 0.6280011340809044]
# Michigan State: [11.775794312083296, 0.46173647962096465]
# Northern Illinois: [11.774549212214113, 0.2602196557868274]
# Buffalo: [13.801713680793464, 0.5545737568728969]
# Temple: [14.5577582086057, 0.3714326684918451]
# BYU: [10.80044080664641, 0.5615076401029077]
# Navy: [12.848304603590353, 0.2898012349979384]
# Pittsburgh: [12.388348249158255, 0.22025547905209286]
# Washington State: [14.132983933189987, 0.2973606750626707]
# LSU: [12.82369609325852, 0.4782801556049239]
# Kent State: [12.316901306782766, 0.6061925039197953]
# Stanford: [12.344413198270514, 0.13211198612547492]
# UCF: [11.729620678346993, 0.37886091620728146]
# Maryland: [13.108496482054857, 0.5835803429791571]
# Florida State: [13.027062285181525, 0.540555156935872]
# North Carolina: [11.957916834833421, 0.29697798816274834]
# Western Kentucky: [15.575449699050983, 0.10963099211376137]
# Kansas State: [11.216346907596078, 0.41725065515256043]
# San Diego State: [12.257404077478, 0.267367967564378]
# Army: [15.620583868200196, 0.49389446131960446]
# Tulsa: [11.306450064695744, 0.5704874579510499]
# Duke: [14.55248836155069, 0.42527351064621144]
# Memphis: [13.140468786001936, 0.5203188636649061]
# Clemson: [11.297087817531155, 0.5190298042602881]
# Syracuse: [14.068044463441149, 0.6419067506715072]
# Hawai'i: [12.285705508530405, 0.42894899557989596]
# East Carolina: [13.971266444796697, 0.513992984715784]
# Fresno State: [13.382874978802452, 0.44652722828152513]
# UNLV: [14.826699173820108, 0.03489321968696146]
# Nevada: [12.372574706681394, 0.5599614503978998]
# Arkansas State: [12.241955936619465, 0.7279108369954725]
# Old Dominion: [12.581613708468614, 0.08540341038602539]
# Penn State: [11.813738429348547, 0.5032754854640642]
# Notre Dame: [14.106483842792457, 0.27892874173499416]
# South Alabama: [14.080711527621995, -1.8259841532128815]
# Wyoming: [12.347702750381037, 0.2452927647732892]
# Northwestern: [11.0943691403014, 0.47915933827406]
# Purdue: [11.74032782973064, 0.45255689332192206]
# Colorado: [12.570875774228385, 0.5672080224793974]
# Illinois: [10.577586340978504, 0.6419363093468753]
# Idaho: [12.45073048718316, 0.5704727005742087]
# New Mexico: [12.477427863610966, 0.6478331381627971]
# Middle Tennessee: [12.68706822884809, 0.41825650311591467]
# Oregon State: [10.379803668813903, 0.46138292225361355]
# Kansas: [13.255777317549137, 0.5255908313173185]
# Nebraska: [11.19236220343362, 0.44013638373666275]
# Ball State: [10.215790116766142, 0.5843803007925855]
# Boise State: [11.222217410961287, 0.32178501921108027]
# Florida Atlantic: [13.471886868916425, 0.36277317882706206]
# West Virginia: [13.272710607954334, 0.5891656838487824]
# Colorado State: [11.296241089380725, 0.4029669311289915]
# Washington: [11.832544908465625, 0.5412568887281997]
# Central Michigan: [10.826060328037935, 0.3560822352522782]
# Georgia State: [14.507470864000137, 0.16108289712849022]
# Utah: [11.725578777704534, 0.46914809313285477]
# Marshall: [13.231918224904978, 0.6255393826166964]
# North Texas: [14.380043544948284, 0.5562716732295847]
# Air Force: [11.839159725389395, 0.5808424125526614]
# UT San Antonio: [10.792986097035998, 0.38255839474484155]
# Oklahoma: [12.400658776441722, 0.3137135400294284]
# Florida: [11.79729447395919, 0.4142277967386485]
# Ohio: [12.583183476772652, 0.5248045764693525]
# Toledo: [11.430650004826166, 0.5551193527534896]
# Oregon: [13.808718972052151, 0.4204600346799191]
# Louisville: [12.726567283484675, 0.5007669350049904]
# Kentucky: [12.667505443016335, 0.7024769038242245]
# Missouri: [12.943652095595052, 0.35522155535203814]
# Rutgers: [12.482588032496404, 0.6790485906371173]
# Arkansas: [12.661740947871, 0.5324430557846327]
# Indiana: [10.160061000059448, 0.576391242315117]

# %%
maeScoresTalent = [value[0] for value in modelScoresTalent.values()]
r2ScoresTalent = [value[1] for value in modelScoresTalent.values()]
print(f'Mean MAE: {np.mean(maeScoresTalent)} \nMean R2 Score: {np.mean(r2ScoresTalent)}')
# Out:
# Mean MAE: 12.502987643519452
# Mean R2 Score: 0.4236140104064987

# %% [markdown]
# Some improvement overall, next let's add S&P+

# %%
# setting the download directory and Chrome settings
directory = "/Users/blaizelahman/Desktop/CFBData"
chromeOptions = webdriver.ChromeOptions()
prefs = {"download.default_directory": directory}
chromeOptions.add_experimental_option("prefs", prefs)

# creating Chrome driver
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()), options = chromeOptions)

# making a dictionary to hold team S&P+ ratings
spRatings = {}

# downloading team S&P+ ratings for years 2005-2023 from collegefootballdata.com
for year in range(2005, 2024):

    # skipping 2020 because it has bad data
    if year == 2020: 
        continue
        
    try:
        url = f'https://collegefootballdata.com/exporter/ratings/sp?year={year}'
        driver.get(url)
        time.sleep(4) 
            
        # clicking the query button
        query = driver.find_element(By.XPATH, "//button[contains(span/text(), 'Query')]")
        query.click()
        time.sleep(3) 
            
        # clicking the export button
        export = driver.find_element(By.XPATH, "//button[contains(span/text(), 'Export')]")
        export.click()
        time.sleep(3)
        
        key = str(year)
            
        # grabs files from CFBData folder
        files = os.listdir(directory)

       # grab the file paths for all files ending in .csv
        filePaths = [os.path.join(directory, name) for name in files if name.endswith('.csv')]

        # grabbing the most recently made file out of those in paths
        file = max(filePaths, key=os.path.getctime)
            
        # loading csv file
        spRatings[key] = pd.read_csv(file)

        # deleting the file after it has been added
        os.remove(file)

    except Exception as e:
        print(f'Cannot grab data for {year}. Error: {e}')

    print(f'Successfully grabbed data for {year}')

driver.quit()
# Out:
# Successfully grabbed data for 2005
# Successfully grabbed data for 2006
# Successfully grabbed data for 2007
# Successfully grabbed data for 2008
# Successfully grabbed data for 2009
# Successfully grabbed data for 2010
# Successfully grabbed data for 2011
# Successfully grabbed data for 2012
# Successfully grabbed data for 2013
# Successfully grabbed data for 2014
# Successfully grabbed data for 2015
# Successfully grabbed data for 2016
# Successfully grabbed data for 2017
# Successfully grabbed data for 2018
# Successfully grabbed data for 2019
# Successfully grabbed data for 2021
# Successfully grabbed data for 2022
# Successfully grabbed data for 2023

# %%
spRatings['2023'][:10]
# Out:
#    Year           Team        Conference  Rating  Ranking  SecondOrderWins  \
# 0  2023       Michigan           Big Ten    31.3      1.0              NaN
# 1  2023        Georgia               SEC    31.2      2.0              NaN
# 2  2023         Oregon           Big Ten    26.2      3.0              NaN
# 3  2023     Ohio State           Big Ten    25.2      4.0              NaN
# 4  2023     Penn State           Big Ten    23.5      5.0              NaN
# 5  2023          Texas               SEC    23.2      6.0              NaN
# 6  2023        Alabama               SEC    23.1      7.0              NaN
# 7  2023     Notre Dame  FBS Independents    20.1      8.0              NaN
# 8  2023  Florida State               ACC    19.4      9.0              NaN
# 9  2023       Missouri               SEC    19.3     10.0              NaN
#
#    Sos  Offense Ranking  Offense Rating  Offense Success  \
# 0  NaN             12.0            36.6              NaN
# 1  NaN              4.0            41.5              NaN
# 2  NaN              1.0            45.0              NaN
# 3  NaN             34.0            31.5              NaN
# 4  NaN             29.0            32.7              NaN
# 5  NaN              6.0            39.3              NaN
# 6  NaN             11.0            36.8              NaN
# 7  NaN             14.0            36.3              NaN
# 8  NaN             22.0            34.1              NaN
# 9  NaN             13.0            36.5              NaN
#
#    Offense Explosiveness  Offense Rushing  Offense Passing  \
# 0                    NaN              NaN              NaN
# 1                    NaN              NaN              NaN
# 2                    NaN              NaN              NaN
# 3                    NaN              NaN              NaN
# 4                    NaN              NaN              NaN
# 5                    NaN              NaN              NaN
# 6                    NaN              NaN              NaN
# 7                    NaN              NaN              NaN
# 8                    NaN              NaN              NaN
# 9                    NaN              NaN              NaN
#
#    Offense StandardDowns  Offense PassingDowns  Offense RunRate  Offense Pace  \
# 0                    NaN                   NaN              NaN           NaN
# 1                    NaN                   NaN              NaN           NaN
# 2                    NaN                   NaN              NaN           NaN
# 3                    NaN                   NaN              NaN           NaN
# 4                    NaN                   NaN              NaN           NaN
# 5                    NaN                   NaN              NaN           NaN
# 6                    NaN                   NaN              NaN           NaN
# 7                    NaN                   NaN              NaN           NaN
# 8                    NaN                   NaN              NaN           NaN
# 9                    NaN                   NaN              NaN           NaN
#
#    Defense Ranking  Defense Rating  Defense Success  Defense Explosiveness  \
# 0              1.0             7.2              NaN                    NaN
# 1              5.0            12.2              NaN                    NaN
# 2             16.0            18.2              NaN                    NaN
# 3              2.0             7.8              NaN                    NaN
# 4              4.0            10.5              NaN                    NaN
# 5             12.0            17.7              NaN                    NaN
# 6              8.0            15.6              NaN                    NaN
# 7             10.0            16.7              NaN                    NaN
# 8              9.0            16.5              NaN                    NaN
# 9             14.0            18.0              NaN                    NaN
#
#    Defense Rushing  Defense Passing  Defense StandardDowns  \
# 0              NaN              NaN                    NaN
# 1              NaN              NaN                    NaN
# 2              NaN              NaN                    NaN
# 3              NaN              NaN                    NaN
# 4              NaN              NaN                    NaN
# 5              NaN              NaN                    NaN
# 6              NaN              NaN                    NaN
# 7              NaN              NaN                    NaN
# 8              NaN              NaN                    NaN
# 9              NaN              NaN                    NaN
#
#    Defense PassingDowns  Defense Havoc Total  Defense Havoc FrontSeven  \
# 0                   NaN                  NaN                       NaN
# 1                   NaN                  NaN                       NaN
# 2                   NaN                  NaN                       NaN
# 3                   NaN                  NaN                       NaN
# 4                   NaN                  NaN                       NaN
# 5                   NaN                  NaN                       NaN
# 6                   NaN                  NaN                       NaN
# 7                   NaN                  NaN                       NaN
# 8                   NaN                  NaN                       NaN
# 9                   NaN                  NaN                       NaN
#
#    Defense Havoc Db  SpecialTeams Rating
# 0               NaN                  1.8
# 1               NaN                  1.9
# 2               NaN                 -0.5
# 3               NaN                  1.5
# 4               NaN                  1.3
# 5               NaN                  1.6
# 6               NaN                  2.0
# 7               NaN                  0.5
# 8               NaN                  1.8
# 9               NaN                  0.8

# %% [markdown]
# Augmenting orignal team's dataframe with S&P their rating

# %%
for team, teamDF in teamDict.items():

    for year in teamDF['Year'].unique():
        
        # checks if year and team is in talentRating
        if str(year) in spRatings.keys():
            
            if team in spRatings[str(year)]['Team'].values:
        
                # grabs the dataframe from that year and the talent rating of that team in that year
                spDF = spRatings[str(year)]
                SP = spDF.loc[spDF['Team'] == team, 'Rating']
    
                # assigns talent column with the corresponding talent ratings for games in the given year
                teamDF.loc[teamDF['Year'] == year, 'SP'] = SP.values[0]

            else:

                teamDF.loc[teamDF['Year'] == year, 'SP'] = np.nan

    teamDict[team] = teamDF

# %% [markdown]
# Function to merge opposing S&P ratings by game

# %%
def mergeSP(team):

    # making a copy of the teams dataframe from teamDict
    teamDF = teamDict[team].copy() 

    teamDF['SP_opp'] = np.nan

    # going through the dataframe and merging the opponent's talent rating column row by row
    for index, row in teamDF.iterrows():

        # grabbing year and each opponent's name to access their talent rating in talentRatings
        year = row['Year']
        oppName = row['School_opp']

        if str(year) in spRatings.keys():

            yearDF = spRatings[str(year)]

            
            # getting the opponent's talent rating column from the game they played the given team
            oppRow = yearDF[yearDF['Team'] == oppName]

            if not oppRow.empty:

                oppSP = oppRow.iloc[0]['Rating']
    
                # merging the opponent's talent column on the row the team plays them
                teamDF.loc[index, 'SP_opp'] = oppSP
        
    return teamDF

# %% [markdown]
# Augmenting dataframes with opponent S&P ratings

# %%
for team in teamDict.keys():
    
    updatedDF = mergeSP(team)
    teamDict[team] = updatedDF

# %% [markdown]
# Adding S&P ratings to the features list

# %%
features.extend(['SP','SP_opp'])

# %% [markdown]
# Testing how the addition of S&P scores effects the scores of all models

# %%
# dictionary to hold each team and their model's score with SP as the newest added feature
modelScoresSP = {}

for team, teamDF in teamDict.items():

    scores = buildModelScore(teamDF, features, 50)
    modelScoresSP[team] = scores
    print(f'{team}: {scores}')
# Out:
# Louisiana Tech: [12.01436637354632, 0.24617953196651332]
# Southern Mississippi: [11.916612195695507, 0.6868037048590575]
# Arizona State: [10.465522042797682, 0.5789267509877005]
# Auburn: [12.436568199510976, 0.7469288697038222]
# Texas Tech: [13.81077731377107, 0.4161022944470657]
# Minnesota: [14.552701960080771, 0.4952782072434171]
# NC State: [11.417637953141835, 0.5288325991106793]
# Georgia: [9.805222125846514, 0.7213179373070939]
# USC: [11.77838175479626, 0.4928799469224523]
# South Florida: [11.46152056930923, 0.43673714579050227]
# Wisconsin: [12.774878550274389, 0.354456366282226]
# Miami: [12.398711803248862, 0.5192683705116107]
# Mississippi State: [12.254733483570726, 0.6395378297067174]
# Houston: [14.575750182981583, 0.4171501931773456]
# San José State: [12.287435183795125, 0.5931538885581595]
# Oklahoma State: [14.262810374811613, 0.33078099503752756]
# UCLA: [13.47893722419, 0.2171831124482676]
# Rice: [11.06922263122651, 0.48555292386747406]
# Texas State: [13.408034320526554, 0.2546039171384651]
# Iowa: [11.321803553564667, -0.045398622255645726]
# Western Michigan: [13.0057466410486, 0.4148210299936653]
# Charlotte: [19.645228551275927, 0.35260785023829166]
# Florida International: [15.290921472869929, 0.27064859648531037]
# Ole Miss: [11.630771274322399, 0.6108776064207466]
# UTEP: [11.331990895455919, 0.5337991183574633]
# Boston College: [10.830903130503486, 0.5223807538442564]
# Troy: [11.132760588365219, 0.47168997262925416]
# Wake Forest: [14.554545398987784, 0.5654416302184708]
# Baylor: [13.614196951958755, 0.32505234406375505]
# Bowling Green: [15.41025067342316, 0.463956495910941]
# TCU: [13.97118125399356, 0.4583735328240156]
# Virginia: [11.48917165204583, 0.34112717561249073]
# Utah State: [13.069555728963376, 0.4892253262641816]
# Appalachian State: [12.39723404236872, 0.0892072478878626]
# Michigan: [11.922901204226793, 0.19807999949016375]
# New Mexico State: [11.81397459670961, 0.6667983028626916]
# SMU: [13.004971991202112, 0.4347262661451682]
# South Carolina: [8.94837111588852, 0.6215259823765402]
# Georgia Southern: [12.384127919469815, -0.10909569748095316]
# Vanderbilt: [13.623508707935951, 0.32268990512959517]
# California: [11.484735151809318, 0.5262536205487878]
# Ohio State: [12.827293943547028, 0.4391710619410246]
# Louisiana Monroe: [13.426868810358775, 0.3669346722542519]
# Louisiana: [12.48440100865311, 0.09002919022441547]
# Eastern Michigan: [12.693697897525412, 0.3402270235399445]
# UMass: [16.032202347704715, 0.5519653494269707]
# Alabama: [11.80955870735615, 0.22917607530201733]
# Miami (OH): [11.33407446118783, 0.5289577043937825]
# Iowa State: [13.14923370724081, 0.19208470346387962]
# Arizona: [15.079428126582187, 0.5799087879309237]
# UAB: [14.147556198977417, 0.618687218967136]
# Akron: [13.252537106647859, 0.5235804567864273]
# Cincinnati: [13.480165809004081, 0.3664103697297556]
# Virginia Tech: [13.638739020085566, 0.3882745263788804]
# Tulane: [10.523196476718157, 0.715476758935804]
# Texas: [13.449951411026746, 0.4030042365817895]
# Connecticut: [12.350034959586731, 0.5300169532142512]
# Georgia Tech: [13.454376492663547, 0.2948362601022214]
# Texas A&M: [10.221089352272458, 0.6643221098722065]
# Tennessee: [12.306472383468735, 0.7537758125898415]
# Michigan State: [12.127167289104246, 0.3090530867940088]
# Northern Illinois: [12.295345520752651, 0.5063906017958576]
# Buffalo: [12.75145440524444, 0.5292283050936731]
# Temple: [13.761795019606534, 0.4762004957756737]
# BYU: [10.808608446810656, 0.669223844142438]
# Navy: [12.844312884998246, 0.33016403942607064]
# Pittsburgh: [12.041085459474619, 0.16786137312845462]
# Washington State: [14.413637104945945, 0.423237797407494]
# LSU: [13.087750759114304, 0.4119408173506699]
# Kent State: [12.124806776452209, 0.6831700801184]
# Stanford: [11.475832287315507, 0.6006678481730321]
# UCF: [11.870226354211189, 0.4286924186403577]
# Maryland: [12.546009900136177, 0.6911648954231917]
# Florida State: [14.047357228655676, 0.6053642898317804]
# North Carolina: [11.992856680312526, 0.3435684822822007]
# Western Kentucky: [15.919754815691416, 0.03627738394520219]
# Kansas State: [12.243115298372384, 0.436661703328894]
# San Diego State: [11.86830135681548, 0.19621701936440406]
# Army: [14.943222528526979, 0.34413402729430087]
# Tulsa: [11.486528351486008, 0.5154812841206463]
# Duke: [13.666997528663032, 0.43837550199950803]
# Memphis: [12.837352259026861, 0.4789154474946199]
# Clemson: [12.092112781537953, 0.44201277533220296]
# Syracuse: [12.536081128208222, 0.520982738722469]
# Hawai'i: [11.915807933024322, 0.5806785502527401]
# East Carolina: [13.086244127054405, 0.47436414589745757]
# Fresno State: [13.945418414973693, 0.4770840215129807]
# UNLV: [14.38412970420145, 0.2706994305561824]
# Nevada: [12.736129063592633, 0.4829799580174241]
# Arkansas State: [11.240539321673413, 0.608241783364468]
# Old Dominion: [11.153165043277587, 0.10534200368678182]
# Penn State: [11.636015607026417, 0.40126413156121676]
# Notre Dame: [12.773131021737715, 0.2914459486078965]
# South Alabama: [11.80019318692369, 0.4282383629488524]
# Wyoming: [13.252019584930295, 0.5927216534144437]
# Northwestern: [12.137487433071323, 0.5068690428972924]
# Purdue: [11.557335588389792, 0.15136749938673855]
# Colorado: [13.196545757960257, 0.5439633406168278]
# Illinois: [11.154289544500232, 0.6858587310779669]
# Idaho: [12.189979682498194, 0.5091501668774384]
# New Mexico: [12.029820235214814, 0.5202342396669941]
# Middle Tennessee: [12.26493335825034, 0.07081796796897166]
# Oregon State: [11.584506777125775, 0.5689096825397383]
# Kansas: [12.635998483842636, 0.23981486026982524]
# Nebraska: [11.15369011925759, 0.5045363213242371]
# Ball State: [11.49297867965879, 0.46266679859528015]
# Boise State: [11.332990831539464, 0.2734731410406167]
# Florida Atlantic: [12.912975183571172, 0.4606328037278328]
# West Virginia: [13.144280049069007, 0.4138126011242652]
# Colorado State: [11.142621349749923, 0.5851242731265786]
# Washington: [11.476234686392177, 0.49226219951376093]
# Central Michigan: [12.406497128730361, 0.4752792822754447]
# Georgia State: [16.219542289720888, 0.2583859243752442]
# Utah: [11.777550244725123, 0.40594250392427855]
# Marshall: [12.494599208449854, 0.48137272520738505]
# North Texas: [13.27753562959695, 0.6675077193476764]
# Air Force: [11.156125884484888, 0.43279825471836664]
# UT San Antonio: [13.182508948855864, 0.5031724530364581]
# Oklahoma: [13.22862996216908, 0.4537916748434102]
# Florida: [12.711364277575214, 0.42761152124287405]
# Ohio: [12.168250297825598, 0.4070320311747224]
# Toledo: [11.242590632628648, 0.42655041557438056]
# Oregon: [14.187783116917206, 0.595022468791961]
# Louisville: [12.647091917977164, 0.49382760304019124]
# Kentucky: [11.56435418489121, 0.5794545126338098]
# Missouri: [13.665763113518853, 0.48407030875646007]
# Rutgers: [11.409841695846268, 0.6463421228184141]
# Arkansas: [12.220017131547696, 0.48946381042686826]
# Indiana: [10.489851612580043, 0.6091945304991134]

# %%
maeScoresSP = [value[0] for value in modelScoresSP.values()]
r2ScoresSP = [value[1] for value in modelScoresSP.values()]
print(f'Mean MAE: {np.mean(maeScoresSP)} \nMean R2 Score: {np.mean(r2ScoresSP)}')
# Out:
# Mean MAE: 12.595896319163796
# Mean R2 Score: 0.444865597469117

# %% [markdown]
# It seems that adding S&P ratings substantially improved the model. Going forward we will add more advanced stats and try out different modeling techniques, but for now we will see how our model stacks up against Vegas in terms of predicting score differentials. In order to do that, we need to augment our data with betting data so that we can see how our model performs against Vegas spreads.

# %% [markdown]
# Importing betting data

# %%
# setting the download directory and Chrome settings
directory = "/Users/blaizelahman/Desktop/CFBData"
chromeOptions = webdriver.ChromeOptions()
prefs = {"download.default_directory": directory}
chromeOptions.add_experimental_option("prefs", prefs)

# creating Chrome driver
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()), options = chromeOptions)

# making a dictionary to hold team betting data
bettingDict = {}

# downloading betting data for years 2035-2023 from collegefootballdata.com
for year in range(2013, 2024):

    # skipping 2020 because it has bad data
    if year == 2020: 
        continue
        
    try:
        url = f'https://collegefootballdata.com/exporter/lines?year={year}&seasonType=regular'
        driver.get(url)
        time.sleep(4) 
            
        # clicking the query button
        query = driver.find_element(By.XPATH, "//button[contains(span/text(), 'Query')]")
        query.click()
        time.sleep(3) 
            
        # clicking the export button
        export = driver.find_element(By.XPATH, "//button[contains(span/text(), 'Export')]")
        export.click()
        time.sleep(3)

        key = str(year)

            
        # grabs files from CFBData folder
        files = os.listdir(directory)
        
        # grab the file paths for all files ending in .csv
        filePaths = [os.path.join(directory, name) for name in files if name.endswith('.csv')]

        # grabbing the most recently made file out of those in paths
        file = max(filePaths, key=os.path.getctime)
            
        # loading csv file
        bettingDict[key] = pd.read_csv(file)

        # deleting the file after it has been added
        os.remove(file)

    except Exception as e:
        print(f'Cannot grab data for {year}. Error: {e}')

    print(f'Successfully grabbed data for {year}')

driver.quit()
# Out:
# Successfully grabbed data for 2013
# Successfully grabbed data for 2014
# Successfully grabbed data for 2015
# Successfully grabbed data for 2016
# Successfully grabbed data for 2017
# Successfully grabbed data for 2018
# Successfully grabbed data for 2019
# Successfully grabbed data for 2021
# Successfully grabbed data for 2022
# Successfully grabbed data for 2023

# %% [markdown]
# Augmenting our already existing data with the betting data from preferred line providers (sportsbooks)

# %%
# setting our preferred line providers
lineProviders = ['DraftKings', 'consensus', 'Bovada']

# combining betting dataframes
combinedBetting = pd.concat(bettingDict.values(), ignore_index = True)

# function to get line from most preferred available line
def getPreferredLine(group, lineProviders):

    # go through preferred lines and if our preferred providers are there, return the line
    for provider in lineProviders:
        preferredLine = group[group['LineProvider'] == provider]

        # if preferred line provider has line, return
        if not preferredLine.empty:
            return preferredLine.iloc[0]

    # returning first available line if none of our preferred ones are available
    return group.iloc[0] 

# getting the preferred line for each individual game
preferredLines = combinedBetting.groupby('Id').apply(lambda x: getPreferredLine(x, lineProviders)).reset_index(drop = True)

# merging the preferred lines with each dataframe in teamDict
for team, teamDF in teamDict.items():
    
    # merging based on Game Id
    teamDict[team] = teamDF.merge(preferredLines, left_on = 'Game Id', right_on = 'Id', how = 'left')

# %% [markdown]
# Looking at new dataframe

# %%
teamDict['Florida State'][teamDict['Florida State']['Year'] == 2023]

# %% [markdown]
# Let's correct the 'Spread' column by getting it into the format of our predictions so that they can be easily compared.

# %%
# function that will change the sign of the spread if the given team is 
# the home team, which will standardize the column
def correctSpread(row, team):
    if row['HomeTeam'] == team:
        row['Spread'] = float(row['Spread']) * -1
    return row

# %%
# applying this correction to all dataframes
for team, teamDF in teamDict.items(): 
    
    teamDict[team] = teamDF.apply(correctSpread, axis = 1, team = team)

# %% [markdown]
# Now we'll save these updated dataframes as csv files to be used in analyzing model success against Vegas

# %%
for key, team in teamDict.items():
    if '2023' in team['Year'].astype(str).values:
        name = key.replace(' ', '_') + '_updated_model.csv'
        team.to_csv(name)
        print('CSV: ' + name)
# Out:
# CSV: Boston_College_updated_model.csv
# CSV: Rutgers_updated_model.csv
# CSV: Auburn_updated_model.csv
# CSV: North_Texas_updated_model.csv
# CSV: Nebraska_updated_model.csv
# CSV: Oklahoma_State_updated_model.csv
# CSV: Arizona_State_updated_model.csv
# CSV: Eastern_Michigan_updated_model.csv
# CSV: Louisiana_updated_model.csv
# CSV: Colorado_State_updated_model.csv
# CSV: Idaho_updated_model.csv
# CSV: Illinois_updated_model.csv
# CSV: Air_Force_updated_model.csv
# CSV: Kent_State_updated_model.csv
# CSV: Louisiana_Monroe_updated_model.csv
# CSV: Iowa_updated_model.csv
# CSV: Akron_updated_model.csv
# CSV: Ohio_updated_model.csv
# CSV: Georgia_updated_model.csv
# CSV: South_Alabama_updated_model.csv
# CSV: Georgia_Tech_updated_model.csv
# CSV: Western_Kentucky_updated_model.csv
# CSV: Maryland_updated_model.csv
# CSV: Arizona_updated_model.csv
# CSV: Minnesota_updated_model.csv
# CSV: Pittsburgh_updated_model.csv
# CSV: Marshall_updated_model.csv
# CSV: Louisiana_Tech_updated_model.csv
# CSV: Virginia_Tech_updated_model.csv
# CSV: California_updated_model.csv
# CSV: Georgia_Southern_updated_model.csv
# CSV: Rice_updated_model.csv
# CSV: Missouri_updated_model.csv
# CSV: UCF_updated_model.csv
# CSV: Kansas_State_updated_model.csv
# CSV: Appalachian_State_updated_model.csv
# CSV: Michigan_updated_model.csv
# CSV: Clemson_updated_model.csv
# CSV: Oregon_updated_model.csv
# CSV: Florida_Atlantic_updated_model.csv
# CSV: Central_Michigan_updated_model.csv
# CSV: Louisville_updated_model.csv
# CSV: Navy_updated_model.csv
# CSV: Washington_State_updated_model.csv
# CSV: Tennessee_updated_model.csv
# CSV: Arkansas_State_updated_model.csv
# CSV: Kansas_updated_model.csv
# CSV: Miami_updated_model.csv
# CSV: Alabama_updated_model.csv
# CSV: Vanderbilt_updated_model.csv
# CSV: USC_updated_model.csv
# CSV: Indiana_updated_model.csv
# CSV: UMass_updated_model.csv
# CSV: Utah_State_updated_model.csv
# CSV: Baylor_updated_model.csv
# CSV: Tulsa_updated_model.csv
# CSV: Ole_Miss_updated_model.csv
# CSV: BYU_updated_model.csv
# CSV: UTEP_updated_model.csv
# CSV: Syracuse_updated_model.csv
# CSV: Middle_Tennessee_updated_model.csv
# CSV: Arkansas_updated_model.csv
# CSV: UT_San_Antonio_updated_model.csv
# CSV: Hawai'i_updated_model.csv
# CSV: Oregon_State_updated_model.csv
# CSV: Southern_Mississippi_updated_model.csv
# CSV: Florida_State_updated_model.csv
# CSV: Texas_A&M_updated_model.csv
# CSV: UAB_updated_model.csv
# CSV: Boise_State_updated_model.csv
# CSV: Duke_updated_model.csv
# CSV: Colorado_updated_model.csv
# CSV: Northern_Illinois_updated_model.csv
# CSV: Coastal_Carolina_updated_model.csv
# CSV: Florida_updated_model.csv
# CSV: Wyoming_updated_model.csv
# CSV: Houston_updated_model.csv
# CSV: Cincinnati_updated_model.csv
# CSV: New_Mexico_updated_model.csv
# CSV: Texas_Tech_updated_model.csv
# CSV: Texas_State_updated_model.csv
# CSV: Temple_updated_model.csv
# CSV: Wisconsin_updated_model.csv
# CSV: Purdue_updated_model.csv
# CSV: Liberty_updated_model.csv
# CSV: East_Carolina_updated_model.csv
# CSV: Old_Dominion_updated_model.csv
# CSV: Oklahoma_updated_model.csv
# CSV: Toledo_updated_model.csv
# CSV: Troy_updated_model.csv
# CSV: Ohio_State_updated_model.csv
# CSV: Penn_State_updated_model.csv
# CSV: Buffalo_updated_model.csv
# CSV: Nevada_updated_model.csv
# CSV: Florida_International_updated_model.csv
# CSV: Iowa_State_updated_model.csv
# CSV: Northwestern_updated_model.csv
# CSV: New_Mexico_State_updated_model.csv
# CSV: South_Carolina_updated_model.csv
# CSV: Memphis_updated_model.csv
# CSV: Western_Michigan_updated_model.csv
# CSV: Miami_(OH)_updated_model.csv
# CSV: South_Florida_updated_model.csv
# CSV: Fresno_State_updated_model.csv
# CSV: Tulane_updated_model.csv
# CSV: NC_State_updated_model.csv
# CSV: Virginia_updated_model.csv
# CSV: Georgia_State_updated_model.csv
# CSV: Bowling_Green_updated_model.csv
# CSV: Ball_State_updated_model.csv
# CSV: Army_updated_model.csv
# CSV: UNLV_updated_model.csv
# CSV: San_José_State_updated_model.csv
# CSV: Stanford_updated_model.csv
# CSV: LSU_updated_model.csv
# CSV: Utah_updated_model.csv
# CSV: Charlotte_updated_model.csv
# CSV: Notre_Dame_updated_model.csv
# CSV: SMU_updated_model.csv
# CSV: UCLA_updated_model.csv
# CSV: Washington_updated_model.csv
# CSV: Michigan_State_updated_model.csv
# CSV: Texas_updated_model.csv
# CSV: West_Virginia_updated_model.csv
# CSV: Mississippi_State_updated_model.csv
# CSV: Connecticut_updated_model.csv
# CSV: Kentucky_updated_model.csv
# CSV: Wake_Forest_updated_model.csv
# CSV: North_Carolina_updated_model.csv
# CSV: San_Diego_State_updated_model.csv
# CSV: TCU_updated_model.csv
